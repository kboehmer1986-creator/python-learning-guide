# %% [markdown]
# # Python Exercises Notebook
#
# This notebook contains **practical exercises** to help you master Python programming. Each section includes exercises with solutions.

# %% [markdown]
# ## Table of Contents
#
# 1. [Variables and Data Types](#Variables-and-Data-Types)
# 2. [Control Flow](#Control-Flow)
# 3. [Functions](#Functions)
# 4. [Data Structures](#Data-Structures)
# 5. [File Handling](#File-Handling)
# 6. [Object-Oriented Programming](#Object-Oriented-Programming)
# 7. [Advanced Topics](#Advanced-Topics)

# %% [markdown]
# ## Variables and Data Types

# %% [markdown]
# ### Exercise 1: Basic Variables
# Create variables for your name, age, and favorite color. Print them in a single line using an f-string.

# %%
# Your code here
name = "Your Name"
age = 25
favorite_color = "blue"
print(f"Name: {name}, Age: {age}, Favorite Color: {favorite_color}")

# %% [markdown]
# ### Exercise 2: User Input
# Ask the user for their name and age, then print a greeting message.

# %%
# Your code here
user_name = input("Enter your name: ")
user_age = input("Enter your age: ")
print(f"Hello, {user_name}! You are {user_age} years old.")

# %% [markdown]
# ### Exercise 3: Type Conversion
# Convert a string number to an integer and a float, then print the types.

# %%
# Your code here
num_str = "123"
num_int = int(num_str)
num_float = float(num_str)
print(f"String: {num_str} (Type: {type(num_str)})")
print(f"Integer: {num_int} (Type: {type(num_int)})")
print(f"Float: {num_float} (Type: {type(num_float)})")

# %% [markdown]
# ## Control Flow

# %% [markdown]
# ### Exercise 4: Conditional Statements
# Write a program that checks if a number is positive, negative, or zero.

# %%
# Your code here
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# ### Exercise 5: For Loop
# Write a for loop to print the first 10 even numbers.

# %%
# Your code here
for i in range(2, 21, 2):
    print(i)

# %% [markdown]
# ### Exercise 6: While Loop
# Write a while loop to print numbers from 10 to 1.

# %%
# Your code here
i = 10
while i >= 1:
    print(i)
    i -= 1

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Exercise 7: Basic Function
# Write a function `is_even(num)` that returns `True` if the number is even, otherwise `False`.

# %%
# Your code here
def is_even(num):
    return num % 2 == 0

# Test the function
print(is_even(4))  # True
print(is_even(5))  # False

# %% [markdown]
# ### Exercise 8: Function with Default Parameters
# Write a function `greet(name, greeting="Hello")` that greets a person with a customizable greeting.

# %%
# Your code here
def greet(name, greeting="Hello"):
    return f"{greeting}, {name}!"

# Test the function
print(greet("Kay"))  # Hello, Kay!
print(greet("Alice", "Hi"))  # Hi, Alice!

# %% [markdown]
# ### Exercise 9: Lambda Function
# Write a lambda function to square a number and test it.

# %%
# Your code here
square = lambda x: x ** 2
print(square(5))  # 25

# %% [markdown]
# ## Data Structures

# %% [markdown]
# ### Exercise 10: List Operations
# Create a list of numbers from 1 to 10, then:
# 1. Append 11 to the list.
# 2. Remove the number 5.
# 3. Print the list.

# %%
# Your code here
numbers = list(range(1, 11))
numbers.append(11)
numbers.remove(5)
print(numbers)

# %% [markdown]
# ### Exercise 11: Dictionary Operations
# Create a dictionary with keys `name`, `age`, and `city`. Then:
# 1. Add a new key `job` with a value.
# 2. Update the `age` value.
# 3. Print the dictionary.

# %%
# Your code here
person = {"name": "Kay", "age": 39, "city": "Erfurt"}
person["job"] = "Developer"
person["age"] = 40
print(person)

# %% [markdown]
# ### Exercise 12: List Comprehension
# Use list comprehension to create a list of squares for numbers from 1 to 10.

# %%
# Your code here
squares = [x**2 for x in range(1, 11)]
print(squares)

# %% [markdown]
# ## File Handling

# %% [markdown]
# ### Exercise 13: Writing to a File
# Write a program that writes the string `Hello, World!` to a file named `hello.txt`.

# %%
# Your code here
with open("hello.txt", "w") as file:
    file.write("Hello, World!")

# %% [markdown]
# ### Exercise 14: Reading from a File
# Write a program that reads the content of `hello.txt` and prints it.

# %%
# Your code here
with open("hello.txt", "r") as file:
    content = file.read()
    print(content)

# %% [markdown]
# ## Object-Oriented Programming

# %% [markdown]
# ### Exercise 15: Basic Class
# Create a class `Person` with attributes `name` and `age`, and a method `greet()` that returns a greeting message.

# %%
# Your code here
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def greet(self):
        return f"Hello, I'm {self.name} and I'm {self.age} years old."

# Test the class
person = Person("Kay", 39)
print(person.greet())

# %% [markdown]
# ### Exercise 16: Inheritance
# Create a class `Student` that inherits from `Person` and adds an attribute `student_id`. Override the `greet()` method to include the student ID.

# %%
# Your code here
class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id
    
    def greet(self):
        return f"Hello, I'm {self.name}, I'm {self.age} years old, and my student ID is {self.student_id}."

# Test the class
student = Student("Alice", 20, "S12345")
print(student.greet())

# %% [markdown]
# ## Advanced Topics

# %% [markdown]
# ### Exercise 17: Decorator
# Write a decorator `timer` that measures the execution time of a function.

# %%
# Your code here
import time

def timer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"{func.__name__} took {end_time - start_time:.4f} seconds")
        return result
    return wrapper

@timer
def slow_function():
    time.sleep(1)
    return "Done"

# Test the decorator
slow_function()

# %% [markdown]
# ### Exercise 18: Generator
# Write a generator function `fibonacci(n)` that yields the first `n` Fibonacci numbers.

# %%
# Your code here
def fibonacci(n):
    a, b = 0, 1
    for _ in range(n):
        yield a
        a, b = b, a + b

# Test the generator
list(fibonacci(10))

# %% [markdown]
# ### Exercise 19: Context Manager
# Write a context manager `Timer` that prints the time taken to execute a block of code.

# %%
# Your code here
import time
from contextlib import contextmanager

@contextmanager
def Timer():
    start_time = time.time()
    yield
    end_time = time.time()
    print(f"Elapsed time: {end_time - start_time:.4f} seconds")

# Test the context manager
with Timer():
    time.sleep(1)

# %% [markdown]
# ### Exercise 20: Multithreading
# Write a program that uses multithreading to print numbers from 1 to 10 in two separate threads.

# %%
# Your code here
import threading

def print_numbers(start, end):
    for i in range(start, end + 1):
        print(i)

# Create threads
thread1 = threading.Thread(target=print_numbers, args=(1, 5))
thread2 = threading.Thread(target=print_numbers, args=(6, 10))

# Start threads
thread1.start()
thread2.start()

# Wait for threads to complete
thread1.join()
thread2.join()

# %% [markdown]
# ## Summary
#
# This notebook provided practical exercises covering:
#
# - **Variables and Data Types**: Basic variable operations
# - **Control Flow**: Conditional statements and loops
# - **Functions**: Defining and using functions
# - **Data Structures**: Lists, dictionaries, and comprehensions
# - **File Handling**: Reading and writing files
# - **Object-Oriented Programming**: Classes and inheritance
# - **Advanced Topics**: Decorators, generators, context managers, and multithreading
#
# Keep practicing these exercises to strengthen your Python skills!
